# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaivargas/machineLearningAgents/blob/master/DeepQLearningCartPole.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y xvfb ffmpeg
# !pip install 'gym==0.10.11'
# !pip install 'imageio==2.4.0'
# !pip install PILLOW
# !pip install 'pyglet==1.3.2'
# !pip install pyvirtualdisplay
# !pip install keras
# !pip install gym
# !pip install box2d-py
# !pip install -q pyyaml h5py
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# xvfb is already the newest version (2:1.19.6-1ubuntu4.4).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Requirement already satisfied: gym==0.10.11 in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym==0.10.11) (1.4.1)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.11) (2.23.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.11) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.11) (1.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym==0.10.11) (1.12.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.11) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.11) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.11) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.11) (2.9)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym==0.10.11) (0.16.0)
# Requirement already satisfied: imageio==2.4.0 in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from imageio==2.4.0) (1.18.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio==2.4.0) (7.0.0)
# Requirement already satisfied: PILLOW in /usr/local/lib/python3.6/dist-packages (7.0.0)
# Collecting pyglet==1.3.2
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 10.1MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet==1.3.2) (0.16.0)
# Installing collected packages: pyglet
#   Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
# Successfully installed pyglet-1.3.2
# Collecting pyvirtualdisplay
#   Downloading https://files.pythonhosted.org/packages/69/ec/8221a07850d69fa3c57c02e526edd23d18c7c05d58ed103e3b19172757c1/PyVirtualDisplay-0.2.5-py2.py3-none-any.whl
# Collecting EasyProcess
#   Downloading https://files.pythonhosted.org/packages/48/3c/75573613641c90c6d094059ac28adb748560d99bd27ee6f80cce398f404e/EasyProcess-0.3-py2.py3-none-any.whl
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-0.3 pyvirtualdisplay-0.2.5
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (2.3.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras) (1.18.4)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras) (3.13)
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.3.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.18.4)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.12.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym) (1.4.1)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym) (0.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (2.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym) (1.24.3)
# Requirement already satisfied: box2d-py in /usr/local/lib/python3.6/dist-packages (2.3.8)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import base64
import imageio

import PIL.Image
import pyvirtualdisplay

import gym
import numpy as np
import tensorflow as tf
from   tensorflow import keras
from   tensorflow.keras.optimizers import Adam
from   tensorflow.keras.models import load_model



display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
# Out:
# xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!

# %%
class ReplayBuffer():
    def __init__(self, max_size, input_dims):
        self.mem_size = max_size
        self.mem_cntr = 0

        self.state_memory = np.zeros((self.mem_size, *input_dims), 
                                    dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims),
                                dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.int32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = 1 - int(done)
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        rewards = self.reward_memory[batch]
        actions = self.action_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

def build_dqn(lr, n_actions, input_dims, fc1_dims, fc2_dims):
    model = keras.Sequential([
        keras.layers.Dense(fc1_dims, activation='relu'),
        keras.layers.Dense(fc2_dims, activation='relu'),
        keras.layers.Dense(n_actions, activation=None)])
    model.compile(optimizer=Adam(learning_rate=lr), loss='mean_squared_error')

    return model

class Agent():
    def __init__(self, lr, gamma, n_actions, epsilon, batch_size,
                input_dims, epsilon_dec=1e-3, epsilon_end=0.01,
                mem_size=1000000, fname='dqn_model.h5'):
        self.action_space = [i for i in range(n_actions)]
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_dec = epsilon_dec
        self.eps_min = epsilon_end
        self.batch_size = batch_size
        self.model_file = fname
        self.memory = ReplayBuffer(mem_size, input_dims)
        self.q_eval = build_dqn(lr, n_actions, input_dims, 256, 256)

    def store_transition(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def choose_action(self, observation):
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_space)
        else:
            state = np.array([observation])
            actions = self.q_eval.predict(state)

            action = np.argmax(actions)

        return action

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        states, actions, rewards, states_, dones = \
                self.memory.sample_buffer(self.batch_size)

        q_eval = self.q_eval.predict(states)
        q_next = self.q_eval.predict(states_)


        q_target = np.copy(q_eval)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        q_target[batch_index, actions] = rewards + \
                        self.gamma * np.max(q_next, axis=1)*dones


        self.q_eval.train_on_batch(states, q_target)

        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > \
                self.eps_min else self.eps_min

    def save_model(self):
        self.q_eval.save(self.model_file)


    def load_model(self):
        self.q_eval = load_model(self.model_file)
     



      
import Box2D
if __name__ == '__main__':
    tf.compat.v1.disable_eager_execution()
    env = gym.make('CartPole-v1')
    lr = 0.0005
    n_games = 500
    agent = Agent(gamma=0.99, epsilon=1.0, lr=lr,
                  input_dims=env.observation_space.shape,
                  n_actions=env.action_space.n, mem_size=1000000, batch_size=64,
                  epsilon_end=0.01)

    #agent.load_model()
    scores = []
    eps_history = []

    for i in range(n_games):
        done = False
        score = 0
        observation = env.reset()
        while not done:
           # env.render()
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent.store_transition(observation, action, reward, observation_, int(done))
            observation = observation_
            agent.learn()

        eps_history.append(agent.epsilon)
        scores.append(score)

        avg_score = np.mean(scores[max(0, i-100):(i+1)])
        print('episode: ', i,'score: %.2f' % score,
              ' average score %.2f' % avg_score)

        if i % 10 == 0 and i > 0:
            agent.save_model()


    x = [i+1 for i in range(n_games)]
# Out:
# episode:  0 score: 18.00  average score 18.00
# episode:  1 score: 19.00  average score 18.50
# episode:  2 score: 15.00  average score 17.33
# episode:  3 score: 25.00  average score 19.25
# episode:  4 score: 15.00  average score 18.40
# episode:  5 score: 11.00  average score 17.17
# episode:  6 score: 23.00  average score 18.00
# episode:  7 score: 21.00  average score 18.38
# episode:  8 score: 17.00  average score 18.22
# episode:  9 score: 30.00  average score 19.40
# episode:  10 score: 22.00  average score 19.64
# episode:  11 score: 14.00  average score 19.17
# episode:  12 score: 23.00  average score 19.46
# episode:  13 score: 42.00  average score 21.07
# episode:  14 score: 19.00  average score 20.93
# episode:  15 score: 24.00  average score 21.12
# episode:  16 score: 11.00  average score 20.53
# episode:  17 score: 14.00  average score 20.17
# episode:  18 score: 15.00  average score 19.89
# episode:  19 score: 12.00  average score 19.50
# episode:  20 score: 13.00  average score 19.19
# episode:  21 score: 17.00  average score 19.09
# episode:  22 score: 21.00  average score 19.17
# episode:  23 score: 15.00  average score 19.00
# episode:  24 score: 14.00  average score 18.80
# episode:  25 score: 10.00  average score 18.46
# episode:  26 score: 12.00  average score 18.22
# episode:  27 score: 16.00  average score 18.14
# episode:  28 score: 12.00  average score 17.93
# episode:  29 score: 17.00  average score 17.90
# episode:  30 score: 12.00  average score 17.71
# episode:  31 score: 12.00  average score 17.53
# episode:  32 score: 11.00  average score 17.33
# episode:  33 score: 18.00  average score 17.35
# episode:  34 score: 9.00  average score 17.11
# episode:  35 score: 8.00  average score 16.86
# episode:  36 score: 10.00  average score 16.68
# episode:  37 score: 14.00  average score 16.61
# episode:  38 score: 11.00  average score 16.46
# episode:  39 score: 9.00  average score 16.27
# episode:  40 score: 14.00  average score 16.22
# episode:  41 score: 11.00  average score 16.10
# episode:  42 score: 12.00  average score 16.00
# episode:  43 score: 9.00  average score 15.84
# episode:  44 score: 8.00  average score 15.67
# episode:  45 score: 13.00  average score 15.61
# episode:  46 score: 9.00  average score 15.47
# episode:  47 score: 11.00  average score 15.38
# episode:  48 score: 17.00  average score 15.41
# episode:  49 score: 12.00  average score 15.34
# episode:  50 score: 9.00  average score 15.22
# episode:  51 score: 13.00  average score 15.17
# episode:  52 score: 11.00  average score 15.09
# episode:  53 score: 16.00  average score 15.11
# episode:  54 score: 8.00  average score 14.98
# episode:  55 score: 8.00  average score 14.86
# episode:  56 score: 10.00  average score 14.77
# episode:  57 score: 12.00  average score 14.72
# episode:  58 score: 10.00  average score 14.64
# episode:  59 score: 13.00  average score 14.62
# episode:  60 score: 10.00  average score 14.54
# episode:  61 score: 10.00  average score 14.47
# episode:  62 score: 18.00  average score 14.52
# episode:  63 score: 11.00  average score 14.47
# episode:  64 score: 9.00  average score 14.38
# episode:  65 score: 9.00  average score 14.30
# episode:  66 score: 10.00  average score 14.24
# episode:  67 score: 10.00  average score 14.18
# episode:  68 score: 10.00  average score 14.12
# episode:  69 score: 9.00  average score 14.04
# episode:  70 score: 9.00  average score 13.97
# episode:  71 score: 9.00  average score 13.90
# episode:  72 score: 9.00  average score 13.84
# episode:  73 score: 9.00  average score 13.77
# episode:  74 score: 10.00  average score 13.72
# episode:  75 score: 12.00  average score 13.70
# episode:  76 score: 9.00  average score 13.64
# episode:  77 score: 10.00  average score 13.59
# episode:  78 score: 10.00  average score 13.54
# episode:  79 score: 10.00  average score 13.50
# episode:  80 score: 10.00  average score 13.46
# episode:  81 score: 11.00  average score 13.43
# episode:  82 score: 13.00  average score 13.42
# episode:  83 score: 11.00  average score 13.39
# episode:  84 score: 16.00  average score 13.42
# episode:  85 score: 24.00  average score 13.55
# episode:  86 score: 20.00  average score 13.62
# episode:  87 score: 16.00  average score 13.65
# episode:  88 score: 14.00  average score 13.65
# episode:  89 score: 25.00  average score 13.78
# episode:  90 score: 32.00  average score 13.98
# episode:  91 score: 16.00  average score 14.00
# episode:  92 score: 18.00  average score 14.04
# episode:  93 score: 37.00  average score 14.29
# episode:  94 score: 32.00  average score 14.47
# episode:  95 score: 22.00  average score 14.55
# episode:  96 score: 28.00  average score 14.69
# episode:  97 score: 25.00  average score 14.80
# episode:  98 score: 31.00  average score 14.96
# episode:  99 score: 30.00  average score 15.11
# episode:  100 score: 32.00  average score 15.28
# episode:  101 score: 69.00  average score 15.78
# episode:  102 score: 28.00  average score 15.87
# episode:  103 score: 30.00  average score 16.02
# episode:  104 score: 25.00  average score 16.02
# episode:  105 score: 24.00  average score 16.11
# episode:  106 score: 42.00  average score 16.42
# episode:  107 score: 47.00  average score 16.65
# episode:  108 score: 27.00  average score 16.71
# episode:  109 score: 63.00  average score 17.17
# episode:  110 score: 26.00  average score 17.13
# episode:  111 score: 41.00  average score 17.32
# episode:  112 score: 57.00  average score 17.74
# episode:  113 score: 32.00  average score 17.83
# episode:  114 score: 46.00  average score 17.87
# episode:  115 score: 52.00  average score 18.20
# episode:  116 score: 102.00  average score 18.97
# episode:  117 score: 65.00  average score 19.50
# episode:  118 score: 95.00  average score 20.31
# episode:  119 score: 66.00  average score 20.81
# episode:  120 score: 60.00  average score 21.29
# episode:  121 score: 42.00  average score 21.57
# episode:  122 score: 38.00  average score 21.78
# episode:  123 score: 112.00  average score 22.68
# episode:  124 score: 92.00  average score 23.45
# episode:  125 score: 101.00  average score 24.31
# episode:  126 score: 57.00  average score 24.77
# episode:  127 score: 45.00  average score 25.10
# episode:  128 score: 96.00  average score 25.89
# episode:  129 score: 70.00  average score 26.47
# episode:  130 score: 53.00  average score 26.82
# episode:  131 score: 44.00  average score 27.14
# episode:  132 score: 89.00  average score 27.90
# episode:  133 score: 48.00  average score 28.27
# episode:  134 score: 60.00  average score 28.68
# episode:  135 score: 55.00  average score 29.14
# episode:  136 score: 131.00  average score 30.36
# episode:  137 score: 40.00  average score 30.65
# episode:  138 score: 95.00  average score 31.46
# episode:  139 score: 58.00  average score 31.92
# episode:  140 score: 77.00  average score 32.59
# episode:  141 score: 90.00  average score 33.35
# episode:  142 score: 46.00  average score 33.69
# episode:  143 score: 74.00  average score 34.31
# episode:  144 score: 79.00  average score 35.00
# episode:  145 score: 64.00  average score 35.55
# episode:  146 score: 30.00  average score 35.72
# episode:  147 score: 42.00  average score 36.05
# episode:  148 score: 66.00  average score 36.59
# episode:  149 score: 52.00  average score 36.94
# episode:  150 score: 58.00  average score 37.40
# episode:  151 score: 133.00  average score 38.62
# episode:  152 score: 74.00  average score 39.23
# episode:  153 score: 44.00  average score 39.55
# episode:  154 score: 47.00  average score 39.86
# episode:  155 score: 107.00  average score 40.84
# episode:  156 score: 87.00  average score 41.62
# episode:  157 score: 118.00  average score 42.69
# episode:  158 score: 90.00  average score 43.47
# episode:  159 score: 103.00  average score 44.39
# episode:  160 score: 106.00  average score 45.31
# episode:  161 score: 103.00  average score 46.23
# episode:  162 score: 109.00  average score 47.21
# episode:  163 score: 132.00  average score 48.34
# episode:  164 score: 141.00  average score 49.62
# episode:  165 score: 144.00  average score 50.96
# episode:  166 score: 158.00  average score 52.44
# episode:  167 score: 178.00  average score 54.10
# episode:  168 score: 137.00  average score 55.36
# episode:  169 score: 190.00  average score 57.14
# episode:  170 score: 210.00  average score 59.13
# episode:  171 score: 194.00  average score 60.96
# episode:  172 score: 215.00  average score 63.00
# episode:  173 score: 226.00  average score 65.15
# episode:  174 score: 213.00  average score 67.17
# episode:  175 score: 199.00  average score 69.04
# episode:  176 score: 205.00  average score 70.95
# episode:  177 score: 200.00  average score 72.84
# episode:  178 score: 241.00  average score 75.13
# episode:  179 score: 183.00  average score 76.84
# episode:  180 score: 200.00  average score 78.72
# episode:  181 score: 200.00  average score 80.60
# episode:  182 score: 163.00  average score 82.11
# episode:  183 score: 160.00  average score 83.56
# episode:  184 score: 150.00  average score 84.94
# episode:  185 score: 231.00  average score 87.07
# episode:  186 score: 202.00  average score 88.83
# episode:  187 score: 167.00  average score 90.29
# episode:  188 score: 188.00  average score 91.99
# episode:  189 score: 178.00  average score 93.61
# episode:  190 score: 176.00  average score 95.11
# episode:  191 score: 216.00  average score 96.93
# episode:  192 score: 222.00  average score 98.97
# episode:  193 score: 214.00  average score 100.91
# episode:  194 score: 237.00  average score 102.89
# episode:  195 score: 148.00  average score 104.04
# episode:  196 score: 176.00  average score 105.56
# episode:  197 score: 195.00  average score 107.22
# episode:  198 score: 229.00  average score 109.24
# episode:  199 score: 156.00  average score 110.48
# episode:  200 score: 198.00  average score 112.14
# episode:  201 score: 169.00  average score 113.50
# episode:  202 score: 236.00  average score 115.15
# episode:  203 score: 214.00  average score 116.99
# episode:  204 score: 209.00  average score 118.76
# episode:  205 score: 191.00  average score 120.41
# episode:  206 score: 190.00  average score 122.05
# episode:  207 score: 212.00  average score 123.73
# episode:  208 score: 187.00  average score 125.12
# episode:  209 score: 225.00  average score 127.08
# episode:  210 score: 205.00  average score 128.49
# episode:  211 score: 247.00  average score 130.67
# episode:  212 score: 282.00  average score 133.06
# episode:  213 score: 227.00  average score 134.74
# episode:  214 score: 194.00  average score 136.35
# episode:  215 score: 260.00  average score 138.47
# episode:  216 score: 208.00  average score 140.01
# episode:  217 score: 209.00  average score 141.07
# episode:  218 score: 171.00  average score 142.12
# episode:  219 score: 228.00  average score 143.44
# episode:  220 score: 193.00  average score 144.69
# episode:  221 score: 191.00  average score 145.99
# episode:  222 score: 233.00  average score 147.88
# episode:  223 score: 185.00  average score 149.34
# episode:  224 score: 263.00  average score 150.83
# episode:  225 score: 223.00  average score 152.13
# episode:  226 score: 192.00  average score 153.03
# episode:  227 score: 182.00  average score 154.27
# episode:  228 score: 191.00  average score 155.71
# episode:  229 score: 227.00  average score 157.01
# episode:  230 score: 213.00  average score 158.43
# episode:  231 score: 209.00  average score 159.97
# episode:  232 score: 256.00  average score 162.07
# episode:  233 score: 158.00  average score 162.75
# episode:  234 score: 209.00  average score 164.35
# episode:  235 score: 224.00  average score 165.97
# episode:  236 score: 216.00  average score 167.56
# episode:  237 score: 186.00  average score 168.11
# episode:  238 score: 216.00  average score 169.85
# episode:  239 score: 201.00  average score 170.90
# episode:  240 score: 185.00  average score 172.16
# episode:  241 score: 176.00  average score 173.14
# episode:  242 score: 204.00  average score 174.27
# episode:  243 score: 166.00  average score 175.46
# episode:  244 score: 183.00  average score 176.53
# episode:  245 score: 166.00  average score 177.40
# episode:  246 score: 159.00  average score 178.34
# episode:  247 score: 181.00  average score 179.83
# episode:  248 score: 202.00  average score 181.42
# episode:  249 score: 235.00  average score 183.09
# episode:  250 score: 162.00  average score 184.18
# episode:  251 score: 265.00  average score 186.23
# episode:  252 score: 185.00  average score 186.74
# episode:  253 score: 172.00  average score 187.71
# episode:  254 score: 170.00  average score 188.96
# episode:  255 score: 175.00  average score 190.23
# episode:  256 score: 228.00  average score 191.43
# episode:  257 score: 214.00  average score 192.68
# episode:  258 score: 181.00  average score 193.31
# episode:  259 score: 270.00  average score 195.09
# episode:  260 score: 283.00  average score 196.87
# episode:  261 score: 500.00  average score 200.77
# episode:  262 score: 213.00  average score 201.86
# episode:  263 score: 173.00  average score 202.50
# episode:  264 score: 185.00  average score 203.02
# episode:  265 score: 365.00  average score 205.24
# episode:  266 score: 228.00  average score 206.07
# episode:  267 score: 233.00  average score 206.81
# episode:  268 score: 410.00  average score 209.11
# episode:  269 score: 205.00  average score 209.78
# episode:  270 score: 213.00  average score 210.01
# episode:  271 score: 240.00  average score 210.31
# episode:  272 score: 204.00  average score 210.41
# episode:  273 score: 187.00  average score 210.13
# episode:  274 score: 202.00  average score 209.89
# episode:  275 score: 168.00  average score 209.45
# episode:  276 score: 198.00  average score 209.44
# episode:  277 score: 177.00  average score 209.16
# episode:  278 score: 179.00  average score 208.95
# episode:  279 score: 199.00  average score 208.53
# episode:  280 score: 180.00  average score 208.50
# episode:  281 score: 206.00  average score 208.56
# episode:  282 score: 193.00  average score 208.50
# episode:  283 score: 202.00  average score 208.88
# episode:  284 score: 216.00  average score 209.44
# episode:  285 score: 213.00  average score 210.06
# episode:  286 score: 178.00  average score 209.53
# episode:  287 score: 184.00  average score 209.36
# episode:  288 score: 182.00  average score 209.50
# episode:  289 score: 184.00  average score 209.47
# episode:  290 score: 171.00  average score 209.40
# episode:  291 score: 186.00  average score 209.50
# episode:  292 score: 189.00  average score 209.23
# episode:  293 score: 196.00  average score 208.97
# episode:  294 score: 152.00  average score 208.36
# episode:  295 score: 155.00  average score 207.54
# episode:  296 score: 177.00  average score 207.83
# episode:  297 score: 188.00  average score 207.95
# episode:  298 score: 185.00  average score 207.85
# episode:  299 score: 201.00  average score 207.57
# episode:  300 score: 168.00  average score 207.69
# episode:  301 score: 195.00  average score 207.66
# episode:  302 score: 174.00  average score 207.71
# episode:  303 score: 156.00  average score 206.92
# episode:  304 score: 174.00  average score 206.52
# episode:  305 score: 141.00  average score 205.85
# episode:  306 score: 127.00  average score 205.22
# episode:  307 score: 149.00  average score 204.81
# episode:  308 score: 154.00  average score 204.24
# episode:  309 score: 184.00  average score 204.21
# episode:  310 score: 154.00  average score 203.50
# episode:  311 score: 198.00  average score 203.44
# episode:  312 score: 158.00  average score 202.55
# episode:  313 score: 179.00  average score 201.53
# episode:  314 score: 168.00  average score 200.95
# episode:  315 score: 142.00  average score 200.44
# episode:  316 score: 143.00  average score 199.28
# episode:  317 score: 170.00  average score 198.90
# episode:  318 score: 143.00  average score 198.25
# episode:  319 score: 163.00  average score 198.17
# episode:  320 score: 150.00  average score 197.40
# episode:  321 score: 186.00  average score 197.33
# episode:  322 score: 145.00  average score 196.87
# episode:  323 score: 181.00  average score 196.36
# episode:  324 score: 163.00  average score 196.14
# episode:  325 score: 114.00  average score 194.66
# episode:  326 score: 144.00  average score 193.88
# episode:  327 score: 179.00  average score 193.75
# episode:  328 score: 153.00  average score 193.47
# episode:  329 score: 187.00  average score 193.43
# episode:  330 score: 155.00  average score 192.71
# episode:  331 score: 176.00  average score 192.35
# episode:  332 score: 185.00  average score 192.11
# episode:  333 score: 160.00  average score 191.16
# episode:  334 score: 169.00  average score 191.27
# episode:  335 score: 152.00  average score 190.70
# episode:  336 score: 171.00  average score 190.18
# episode:  337 score: 149.00  average score 189.51
# episode:  338 score: 153.00  average score 189.19
# episode:  339 score: 152.00  average score 188.55
# episode:  340 score: 163.00  average score 188.18
# episode:  341 score: 180.00  average score 188.13
# episode:  342 score: 99.00  average score 187.37
# episode:  343 score: 152.00  average score 186.85
# episode:  344 score: 143.00  average score 186.62
# episode:  345 score: 173.00  average score 186.52
# episode:  346 score: 155.00  average score 186.42
# episode:  347 score: 155.00  average score 186.38
# episode:  348 score: 147.00  average score 186.04
# episode:  349 score: 147.00  average score 185.50
# episode:  350 score: 134.00  average score 184.50
# episode:  351 score: 104.00  average score 183.92
# episode:  352 score: 144.00  average score 182.72
# episode:  353 score: 154.00  average score 182.42
# episode:  354 score: 140.00  average score 182.10
# episode:  355 score: 137.00  average score 181.77
# episode:  356 score: 150.00  average score 181.52
# episode:  357 score: 242.00  average score 181.66
# episode:  358 score: 148.00  average score 181.01
# episode:  359 score: 134.00  average score 180.54
# episode:  360 score: 100.00  average score 178.86
# episode:  361 score: 133.00  average score 177.38
# episode:  362 score: 135.00  average score 173.76
# episode:  363 score: 103.00  average score 172.67
# episode:  364 score: 109.00  average score 172.04
# episode:  365 score: 9.00  average score 170.30
# episode:  366 score: 10.00  average score 166.78
# episode:  367 score: 13.00  average score 164.65
# episode:  368 score: 58.00  average score 162.92
# episode:  369 score: 16.00  average score 159.02
# episode:  370 score: 10.00  average score 157.09
# episode:  371 score: 13.00  average score 155.11
# episode:  372 score: 13.00  average score 152.86
# episode:  373 score: 12.00  average score 150.96
# episode:  374 score: 14.00  average score 149.25
# episode:  375 score: 13.00  average score 147.38
# episode:  376 score: 10.00  average score 145.81
# episode:  377 score: 12.00  average score 143.97
# episode:  378 score: 11.00  average score 142.33
# episode:  379 score: 10.00  average score 140.65
# episode:  380 score: 12.00  average score 138.80
# episode:  381 score: 12.00  average score 137.14
# episode:  382 score: 10.00  average score 135.20
# episode:  383 score: 10.00  average score 133.39
# episode:  384 score: 11.00  average score 131.50
# episode:  385 score: 13.00  average score 129.49
# episode:  386 score: 12.00  average score 127.50
# episode:  387 score: 14.00  average score 125.87
# episode:  388 score: 11.00  average score 124.16
# episode:  389 score: 12.00  average score 122.48
# episode:  390 score: 12.00  average score 120.77
# episode:  391 score: 12.00  average score 119.20
# episode:  392 score: 11.00  average score 117.47
# episode:  393 score: 11.00  average score 115.70
# episode:  394 score: 10.00  average score 113.86
# episode:  395 score: 9.00  average score 112.45
# episode:  396 score: 10.00  average score 111.01
# episode:  397 score: 12.00  average score 109.38
# episode:  398 score: 13.00  average score 107.64
# episode:  399 score: 10.00  average score 105.91
# episode:  400 score: 14.00  average score 104.06
# episode:  401 score: 14.00  average score 102.53
# episode:  402 score: 15.00  average score 100.75
# episode:  403 score: 17.00  average score 99.20
# episode:  404 score: 16.00  average score 97.81
# episode:  405 score: 16.00  average score 96.25
# episode:  406 score: 19.00  average score 95.04
# episode:  407 score: 20.00  average score 93.98
# episode:  408 score: 33.00  average score 92.83
# episode:  409 score: 101.00  average score 92.31
# episode:  410 score: 104.00  average score 91.51
# episode:  411 score: 118.00  average score 91.16
# episode:  412 score: 128.00  average score 90.47
# episode:  413 score: 146.00  average score 90.35
# episode:  414 score: 227.00  average score 90.82
# episode:  415 score: 403.00  average score 93.15
# episode:  416 score: 210.00  average score 93.82
# episode:  417 score: 244.00  average score 94.82
# episode:  418 score: 382.00  average score 96.92
# episode:  419 score: 220.00  average score 97.68
# episode:  420 score: 182.00  average score 97.87
# episode:  421 score: 187.00  average score 98.24
# episode:  422 score: 181.00  average score 98.19
# episode:  423 score: 150.00  average score 98.24
# episode:  424 score: 151.00  average score 97.94
# episode:  425 score: 162.00  average score 97.93
# episode:  426 score: 121.00  average score 98.00
# episode:  427 score: 95.00  average score 97.51
# episode:  428 score: 173.00  average score 97.46
# episode:  429 score: 170.00  average score 97.62
# episode:  430 score: 167.00  average score 97.43
# episode:  431 score: 186.00  average score 97.73
# episode:  432 score: 284.00  average score 98.80
# episode:  433 score: 180.00  average score 98.75
# episode:  434 score: 170.00  average score 98.85
# episode:  435 score: 175.00  average score 98.91
# episode:  436 score: 175.00  average score 99.14
# episode:  437 score: 200.00  average score 99.43
# episode:  438 score: 180.00  average score 99.73
# episode:  439 score: 252.00  average score 100.71
# episode:  440 score: 197.00  average score 101.16
# episode:  441 score: 184.00  average score 101.37
# episode:  442 score: 172.00  average score 101.29
# episode:  443 score: 241.00  average score 102.69
# episode:  444 score: 173.00  average score 102.90
# episode:  445 score: 188.00  average score 103.35
# episode:  446 score: 174.00  average score 103.36
# episode:  447 score: 195.00  average score 103.75
# episode:  448 score: 180.00  average score 104.00
# episode:  449 score: 191.00  average score 104.44
# episode:  450 score: 171.00  average score 104.67
# episode:  451 score: 156.00  average score 104.89
# episode:  452 score: 179.00  average score 105.63
# episode:  453 score: 189.00  average score 106.08
# episode:  454 score: 204.00  average score 106.57
# episode:  455 score: 256.00  average score 107.72
# episode:  456 score: 186.00  average score 108.21
# episode:  457 score: 164.00  average score 108.35
# episode:  458 score: 160.00  average score 107.53
# episode:  459 score: 156.00  average score 107.61
# episode:  460 score: 169.00  average score 107.96
# episode:  461 score: 142.00  average score 108.38
# episode:  462 score: 149.00  average score 108.53
# episode:  463 score: 151.00  average score 108.69
# episode:  464 score: 145.00  average score 109.11
# episode:  465 score: 170.00  average score 109.71
# episode:  466 score: 164.00  average score 111.25
# episode:  467 score: 168.00  average score 112.81
# episode:  468 score: 191.00  average score 114.57
# episode:  469 score: 175.00  average score 115.73
# episode:  470 score: 194.00  average score 117.50
# episode:  471 score: 220.00  average score 119.57
# episode:  472 score: 214.00  average score 121.56
# episode:  473 score: 182.00  average score 123.24
# episode:  474 score: 180.00  average score 124.90
# episode:  475 score: 246.00  average score 127.20
# episode:  476 score: 161.00  average score 128.66
# episode:  477 score: 150.00  average score 130.05
# episode:  478 score: 198.00  average score 131.89
# episode:  479 score: 204.00  average score 133.80
# episode:  480 score: 149.00  average score 135.18
# episode:  481 score: 172.00  average score 136.76
# episode:  482 score: 17.00  average score 136.81
# episode:  483 score: 77.00  average score 137.48
# episode:  484 score: 118.00  average score 138.54
# episode:  485 score: 126.00  average score 139.68
# episode:  486 score: 275.00  average score 142.28
# episode:  487 score: 316.00  average score 145.29
# episode:  488 score: 228.00  average score 147.41
# episode:  489 score: 189.00  average score 149.17
# episode:  490 score: 226.00  average score 151.29
# episode:  491 score: 338.00  average score 154.51
# episode:  492 score: 252.00  average score 156.89
# episode:  493 score: 268.00  average score 159.44
# episode:  494 score: 119.00  average score 160.50
# episode:  495 score: 224.00  average score 162.62
# episode:  496 score: 500.00  average score 167.49
# episode:  497 score: 206.00  average score 169.43
# episode:  498 score: 176.00  average score 171.05
# episode:  499 score: 177.00  average score 172.67
