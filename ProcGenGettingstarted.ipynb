# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaivargas/machineLearningAgents/blob/master/ProcGenGettingstarted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ProcGen BenchMark
# https://openai.com/blog/procgen-benchmark/

# %%
# install ProcGen 
pip install procgen

# %%
# Library to record from virtual Frame Buffer
# !sudo apt-get install -y xvfb ffmpeg
# Install Gym library 
# !pip  install 'gym==0.10.11'
# Imageio is a Python library that provides an easy interface to read and write a wide range of image data, including animated images, volumetric data, and scientific formats
# !pip  install 'imageio==2.4.0'
# PIL is the Python Imaging Library
# !pip  install PILLOW
# pyglet is a cross-platform windowing and multimedia library for Python, intended for developing games and other visually rich applications
# !pip  install 'pyglet==1.3.2'
# pyvirtualdisplay is a python wrapper for Xvfb, Xephyr and Xvnc
# !pip  install pyvirtualdisplay
# tf_library for proability distributions.
# !pip  install --upgrade tensorflow-probability
# Api for tf_Agents 
# !pip  install tf-agents

# %%
from __future__ import division

from __future__ import print_function

import base64
import imageio
import IPython
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import PIL.Image
import pyvirtualdisplay

import tensorflow as tf

from tf_agents.agents.reinforce import reinforce_agent
from tf_agents.drivers import dynamic_step_driver
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.eval import metric_utils
from tf_agents.metrics import tf_metrics
from tf_agents.networks import actor_distribution_network
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.trajectories import trajectory
from tf_agents.utils import common

tf.compat.v1.enable_v2_behavior()


# Set up a virtual display for rendering OpenAI gym environments.
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
# Out:
# xdpyinfo was not found, X start can not be checked! Please install xdpyinfo!

# %%
# This comand is the original in python env = gym.make('procgen:procgen-coinrun-v0')
# All the possible are the 16 environments: bigfish,bossfight,caveflyer,chaser,climber,coinrun,dodgeball,fruitbot,heist,jumper,leaper,maze,miner,ninja,plunder,starpilot
# if you want know all environments characteristics in detail you can checkout in https://github.com/openai/procgen
# if you want to use a procgen environment you need to use the name of the environment + -v0 
# Example: procgen:procgen-bigfish-v0 ,procgen:procgen-coinrun-v0 ...etc
procgenEnv = 'procgen:procgen-coinrun-v0'
# tf_Agent Api comand to load the environment from OpenAiEnvironment. 
env = suite_gym.load(procgenEnv)
env.reset()
# Use of PIL.Image.fromarray( envName ) to display an image of the env.
PIL.Image.fromarray(env.render())
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F12DBDFFF60>
