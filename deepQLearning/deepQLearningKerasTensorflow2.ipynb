# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaivargas/machineLearningAgents/blob/master/deepQLearningKerasTensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Deep Q-Learning

# %% [markdown]
# 1.   Preprocess and feed the game screen (state s) to our DQN, which will return the Q-values of all possible actions in the state
# 2.   Select an action using the epsilon-greedy policy. With the probability epsilon, we select a random action a and with probability 1-epsilon, we select an action that has a maximum Q-value, such as a = argmax(Q(s,a,w))
# 3. Perform this action in a state s and move to a new state s’ to receive a reward. This state s’ is the preprocessed image of the next game screen. We store this transition in our replay buffer as <s,a,r,s’>
# 4. Next, sample some random batches of transitions from the replay buffer and calculate the loss.
# 5. It is known the loss function is just the squared difference between target Q and predicted Q
# 6. Perform gradient descent with respect to our actual network parameters in order to minimize this loss
# 7. After every A iterations, copy our actual network weights to the target network weights
# 8. Repeat these steps for N number of episodes

# %%
# !sudo apt-get install -y xvfb ffmpeg
# !pip install 'gym==0.10.11'
# !pip install 'imageio==2.4.0'
# !pip install PILLOW
# !pip install 'pyglet==1.3.2'
# !pip install pyvirtualdisplay
# !pip install keras
# !pip install gym
# !pip install box2d-py
# !pip install -q pyyaml h5py

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import base64
import imageio

import PIL.Image
import pyvirtualdisplay

import gym
import numpy as np
import tensorflow as tf
from   tensorflow import keras
from   tensorflow.keras.optimizers import Adam
from   tensorflow.keras.models import load_model



display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %%
class ReplayBuffer():
    def __init__(self, max_size, input_dims):
        self.mem_size = max_size
        self.mem_cntr = 0

        self.state_memory = np.zeros((self.mem_size, *input_dims), 
                                    dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_dims),
                                dtype=np.float32)
        self.action_memory = np.zeros(self.mem_size, dtype=np.int32)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.int32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.reward_memory[index] = reward
        self.action_memory[index] = action
        self.terminal_memory[index] = 1 - int(done)
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)

        states = self.state_memory[batch]
        states_ = self.new_state_memory[batch]
        rewards = self.reward_memory[batch]
        actions = self.action_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

def build_dqn(lr, n_actions, input_dims, fc1_dims, fc2_dims):
    model = keras.Sequential([
        keras.layers.Dense(fc1_dims, activation='relu'),
        keras.layers.Dense(fc2_dims, activation='relu'),
        keras.layers.Dense(n_actions, activation=None)])
    model.compile(optimizer=Adam(learning_rate=lr), loss='mean_squared_error')

    return model

class Agent():
    def __init__(self, lr, gamma, n_actions, epsilon, batch_size,
                input_dims, epsilon_dec=1e-3, epsilon_end=0.01,
                mem_size=1000000, fname='dqn_model.h5'):
        self.action_space = [i for i in range(n_actions)]
        self.gamma = gamma
        self.epsilon = epsilon
        self.eps_dec = epsilon_dec
        self.eps_min = epsilon_end
        self.batch_size = batch_size
        self.model_file = fname
        self.memory = ReplayBuffer(mem_size, input_dims)
        self.q_eval = build_dqn(lr, n_actions, input_dims, 256, 256)

    def store_transition(self, state, action, reward, new_state, done):
        self.memory.store_transition(state, action, reward, new_state, done)

    def choose_action(self, observation):
        if np.random.random() < self.epsilon:
            action = np.random.choice(self.action_space)
        else:
            state = np.array([observation])
            actions = self.q_eval.predict(state)

            action = np.argmax(actions)

        return action

    def learn(self):
        if self.memory.mem_cntr < self.batch_size:
            return

        states, actions, rewards, states_, dones = \
                self.memory.sample_buffer(self.batch_size)

        q_eval = self.q_eval.predict(states)
        q_next = self.q_eval.predict(states_)


        q_target = np.copy(q_eval)
        batch_index = np.arange(self.batch_size, dtype=np.int32)

        q_target[batch_index, actions] = rewards + \
                        self.gamma * np.max(q_next, axis=1)*dones


        self.q_eval.train_on_batch(states, q_target)

        self.epsilon = self.epsilon - self.eps_dec if self.epsilon > \
                self.eps_min else self.eps_min

    def save_model(self):
        self.q_eval.save(self.model_file)


    def load_model(self):
        self.q_eval = load_model(self.model_file)
     



      
import Box2D
if __name__ == '__main__':
    tf.compat.v1.disable_eager_execution()
    env = gym.make('LunarLander-v2')
    lr = 0.001
    n_games = 500
    agent = Agent(gamma=0.99, epsilon=1.0, lr=lr, 
                input_dims=env.observation_space.shape,
                n_actions=env.action_space.n, mem_size=1000000, batch_size=64,
                epsilon_end=0.01)
    scores = []
    eps_history = []

    for i in range(n_games):
        done = False
        score = 0
        observation = env.reset()
        while not done:
            action = agent.choose_action(observation)
            observation_, reward, done, info = env.step(action)
            score += reward
            agent.store_transition(observation, action, reward, observation_, done)
            observation = observation_
            agent.learn()
        eps_history.append(agent.epsilon)
        scores.append(score)

        avg_score = np.mean(scores[-100:])
        print('episode: ', i, 'score %.2f' % score,
                'average_score %.2f' % avg_score,
                'epsilon %.2f' % agent.epsilon)
   #agent.save_model()
# Out:
# episode:  0 score -301.19 average_score -301.19 epsilon 0.96
# episode:  1 score -305.61 average_score -303.40 epsilon 0.88
# episode:  2 score -85.04 average_score -230.61 epsilon 0.82
# episode:  3 score -105.72 average_score -199.39 epsilon 0.72
# episode:  4 score -139.00 average_score -187.31 epsilon 0.58
# episode:  5 score -256.74 average_score -198.88 epsilon 0.42
# episode:  6 score -93.27 average_score -183.80 epsilon 0.29
# episode:  7 score -128.09 average_score -176.83 epsilon 0.01
# episode:  8 score -73.13 average_score -165.31 epsilon 0.01
# episode:  9 score -301.71 average_score -178.95 epsilon 0.01
# episode:  10 score -74.15 average_score -169.42 epsilon 0.01
# episode:  11 score -306.81 average_score -180.87 epsilon 0.01
# episode:  12 score -141.10 average_score -177.81 epsilon 0.01
# episode:  13 score -28.55 average_score -167.15 epsilon 0.01
# episode:  14 score -198.80 average_score -169.26 epsilon 0.01
# episode:  15 score -104.76 average_score -165.23 epsilon 0.01
# episode:  16 score -86.80 average_score -160.62 epsilon 0.01
# episode:  17 score -79.64 average_score -156.12 epsilon 0.01
# episode:  18 score -503.00 average_score -174.37 epsilon 0.01
# episode:  19 score -79.41 average_score -169.63 epsilon 0.01
# episode:  20 score -102.98 average_score -166.45 epsilon 0.01
# episode:  21 score -84.09 average_score -162.71 epsilon 0.01
# episode:  22 score -126.69 average_score -161.14 epsilon 0.01
# episode:  23 score -36.49 average_score -155.95 epsilon 0.01
# episode:  24 score -64.20 average_score -152.28 epsilon 0.01
# episode:  25 score -102.72 average_score -150.37 epsilon 0.01
# episode:  26 score -38.40 average_score -146.23 epsilon 0.01
# episode:  27 score -77.85 average_score -143.78 epsilon 0.01
# episode:  28 score -35.28 average_score -140.04 epsilon 0.01
# episode:  29 score -69.03 average_score -137.67 epsilon 0.01
# episode:  30 score -198.56 average_score -139.64 epsilon 0.01
# episode:  31 score -79.04 average_score -137.75 epsilon 0.01
# episode:  32 score -16.77 average_score -134.08 epsilon 0.01
# episode:  33 score -36.49 average_score -131.21 epsilon 0.01
# episode:  34 score -58.26 average_score -129.12 epsilon 0.01
# episode:  35 score -33.71 average_score -126.47 epsilon 0.01
# episode:  36 score -85.69 average_score -125.37 epsilon 0.01
# episode:  37 score -65.34 average_score -123.79 epsilon 0.01
# episode:  38 score -89.13 average_score -122.90 epsilon 0.01
# episode:  39 score 197.47 average_score -114.89 epsilon 0.01
# episode:  40 score -120.66 average_score -115.03 epsilon 0.01
# episode:  41 score -36.54 average_score -113.17 epsilon 0.01
# episode:  42 score -53.71 average_score -111.78 epsilon 0.01
# episode:  43 score -45.59 average_score -110.28 epsilon 0.01
# episode:  44 score 136.83 average_score -104.79 epsilon 0.01
# episode:  45 score -115.01 average_score -105.01 epsilon 0.01
# episode:  46 score -38.10 average_score -103.59 epsilon 0.01
# episode:  47 score 6.11 average_score -101.30 epsilon 0.01
# episode:  48 score 13.09 average_score -98.97 epsilon 0.01
# episode:  49 score -17.73 average_score -97.34 epsilon 0.01
# episode:  50 score 11.00 average_score -95.22 epsilon 0.01
# episode:  51 score -71.60 average_score -94.76 epsilon 0.01
# episode:  52 score -9.94 average_score -93.16 epsilon 0.01
# episode:  53 score -50.66 average_score -92.37 epsilon 0.01
# episode:  54 score -58.44 average_score -91.76 epsilon 0.01
# episode:  55 score -26.88 average_score -90.60 epsilon 0.01
# episode:  56 score -530.87 average_score -98.32 epsilon 0.01
# episode:  57 score -31.86 average_score -97.18 epsilon 0.01
# episode:  58 score 13.55 average_score -95.30 epsilon 0.01
# episode:  59 score -167.93 average_score -96.51 epsilon 0.01
# episode:  60 score -36.34 average_score -95.52 epsilon 0.01
# episode:  61 score 116.52 average_score -92.10 epsilon 0.01
# episode:  62 score -80.37 average_score -91.92 epsilon 0.01
# episode:  63 score -59.32 average_score -91.41 epsilon 0.01
# episode:  64 score -86.03 average_score -91.33 epsilon 0.01
# episode:  65 score -60.76 average_score -90.86 epsilon 0.01
# episode:  66 score 190.52 average_score -86.66 epsilon 0.01
# episode:  67 score 128.01 average_score -83.51 epsilon 0.01
# episode:  68 score -47.48 average_score -82.98 epsilon 0.01
# episode:  69 score -17.17 average_score -82.04 epsilon 0.01
# episode:  70 score 15.74 average_score -80.67 epsilon 0.01
# episode:  71 score -194.97 average_score -82.25 epsilon 0.01
# episode:  72 score -48.19 average_score -81.79 epsilon 0.01
# episode:  73 score -205.69 average_score -83.46 epsilon 0.01
# episode:  74 score 180.33 average_score -79.95 epsilon 0.01
# episode:  75 score -0.57 average_score -78.90 epsilon 0.01
# episode:  76 score 32.48 average_score -77.45 epsilon 0.01
# episode:  77 score -297.43 average_score -80.27 epsilon 0.01
# episode:  78 score 188.01 average_score -76.88 epsilon 0.01
# episode:  79 score 40.76 average_score -75.41 epsilon 0.01
# episode:  80 score -25.47 average_score -74.79 epsilon 0.01
# episode:  81 score 181.50 average_score -71.67 epsilon 0.01
# episode:  82 score 61.79 average_score -70.06 epsilon 0.01
# episode:  83 score 38.31 average_score -68.77 epsilon 0.01
# episode:  84 score 12.11 average_score -67.82 epsilon 0.01
# episode:  85 score -64.45 average_score -67.78 epsilon 0.01
# episode:  86 score -317.35 average_score -70.65 epsilon 0.01
# episode:  87 score -141.04 average_score -71.45 epsilon 0.01
# episode:  88 score -114.95 average_score -71.93 epsilon 0.01
# episode:  89 score -84.67 average_score -72.08 epsilon 0.01
# episode:  90 score 160.17 average_score -69.52 epsilon 0.01
# episode:  91 score 193.75 average_score -66.66 epsilon 0.01
# episode:  92 score 16.92 average_score -65.76 epsilon 0.01
# episode:  93 score -15.41 average_score -65.23 epsilon 0.01
# episode:  94 score -191.09 average_score -66.55 epsilon 0.01
# episode:  95 score 38.45 average_score -65.46 epsilon 0.01
# episode:  96 score -103.29 average_score -65.85 epsilon 0.01
# episode:  97 score 146.82 average_score -63.68 epsilon 0.01
# episode:  98 score -49.64 average_score -63.54 epsilon 0.01
# episode:  99 score 24.13 average_score -62.66 epsilon 0.01
# episode:  100 score 1.92 average_score -59.63 epsilon 0.01
# episode:  101 score -59.17 average_score -57.17 epsilon 0.01
# episode:  102 score 197.68 average_score -54.34 epsilon 0.01
# episode:  103 score 7.98 average_score -53.20 epsilon 0.01
# episode:  104 score 9.31 average_score -51.72 epsilon 0.01
# episode:  105 score -123.33 average_score -50.38 epsilon 0.01
# episode:  106 score -188.65 average_score -51.34 epsilon 0.01
# episode:  107 score 169.23 average_score -48.36 epsilon 0.01
# episode:  108 score 97.66 average_score -46.66 epsilon 0.01
# episode:  109 score 280.51 average_score -40.83 epsilon 0.01
# episode:  110 score 226.94 average_score -37.82 epsilon 0.01
# episode:  111 score -136.31 average_score -36.12 epsilon 0.01
# episode:  112 score -48.54 average_score -35.19 epsilon 0.01
# episode:  113 score 199.96 average_score -32.91 epsilon 0.01
# episode:  114 score 204.37 average_score -28.88 epsilon 0.01
# episode:  115 score 207.12 average_score -25.76 epsilon 0.01
# episode:  116 score 192.34 average_score -22.97 epsilon 0.01
# episode:  117 score -62.19 average_score -22.79 epsilon 0.01
# episode:  118 score 179.08 average_score -15.97 epsilon 0.01
# episode:  119 score 267.41 average_score -12.50 epsilon 0.01
# episode:  120 score 178.84 average_score -9.68 epsilon 0.01
# episode:  121 score 282.29 average_score -6.02 epsilon 0.01
# episode:  122 score 109.09 average_score -3.66 epsilon 0.01
# episode:  123 score 21.30 average_score -3.08 epsilon 0.01
# episode:  124 score 217.51 average_score -0.27 epsilon 0.01
# episode:  125 score 204.23 average_score 2.80 epsilon 0.01
# episode:  126 score 53.94 average_score 3.73 epsilon 0.01
# episode:  127 score -299.05 average_score 1.51 epsilon 0.01
# episode:  128 score -32.84 average_score 1.54 epsilon 0.01
# episode:  129 score 215.36 average_score 4.38 epsilon 0.01
# episode:  130 score 198.20 average_score 8.35 epsilon 0.01
# episode:  131 score 252.47 average_score 11.66 epsilon 0.01
# episode:  132 score 196.67 average_score 13.80 epsilon 0.01
# episode:  133 score 253.41 average_score 16.70 epsilon 0.01
# episode:  134 score 218.36 average_score 19.46 epsilon 0.01
# episode:  135 score 211.58 average_score 21.92 epsilon 0.01
# episode:  136 score 26.23 average_score 23.04 epsilon 0.01
# episode:  137 score 212.05 average_score 25.81 epsilon 0.01
# episode:  138 score 291.01 average_score 29.61 epsilon 0.01
# episode:  139 score 11.47 average_score 27.75 epsilon 0.01
# episode:  140 score 241.05 average_score 31.37 epsilon 0.01
# episode:  141 score 213.33 average_score 33.87 epsilon 0.01
# episode:  142 score -6.84 average_score 34.34 epsilon 0.01
# episode:  143 score 239.13 average_score 37.18 epsilon 0.01
# episode:  144 score -40.21 average_score 35.41 epsilon 0.01
# episode:  145 score 234.36 average_score 38.91 epsilon 0.01
# episode:  146 score 190.60 average_score 41.19 epsilon 0.01
# episode:  147 score 242.73 average_score 43.56 epsilon 0.01
# episode:  148 score 190.98 average_score 45.34 epsilon 0.01
# episode:  149 score 187.03 average_score 47.39 epsilon 0.01
# episode:  150 score 253.43 average_score 49.81 epsilon 0.01
# episode:  151 score 227.83 average_score 52.80 epsilon 0.01
# episode:  152 score 210.49 average_score 55.01 epsilon 0.01
# episode:  153 score 257.04 average_score 58.09 epsilon 0.01
# episode:  154 score 28.49 average_score 58.96 epsilon 0.01
# episode:  155 score 205.62 average_score 61.28 epsilon 0.01
# episode:  156 score 182.18 average_score 68.41 epsilon 0.01
# episode:  157 score -12.81 average_score 68.60 epsilon 0.01
# episode:  158 score -322.44 average_score 65.24 epsilon 0.01
# episode:  159 score -96.78 average_score 65.95 epsilon 0.01
# episode:  160 score -65.96 average_score 65.66 epsilon 0.01
# episode:  161 score -89.22 average_score 63.60 epsilon 0.01
# episode:  162 score 181.49 average_score 66.22 epsilon 0.01
# episode:  163 score 246.40 average_score 69.27 epsilon 0.01
# episode:  164 score 232.58 average_score 72.46 epsilon 0.01
# episode:  165 score 264.61 average_score 75.71 epsilon 0.01
# episode:  166 score 1.16 average_score 73.82 epsilon 0.01
# episode:  167 score 299.43 average_score 75.54 epsilon 0.01
# episode:  168 score -110.34 average_score 74.91 epsilon 0.01
# episode:  169 score 239.79 average_score 77.48 epsilon 0.01
# episode:  170 score 113.06 average_score 78.45 epsilon 0.01
# episode:  171 score 236.38 average_score 82.76 epsilon 0.01
# episode:  172 score 245.99 average_score 85.70 epsilon 0.01
# episode:  173 score 276.34 average_score 90.53 epsilon 0.01
# episode:  174 score 249.67 average_score 91.22 epsilon 0.01
# episode:  175 score 278.80 average_score 94.01 epsilon 0.01
# episode:  176 score 205.35 average_score 95.74 epsilon 0.01
# episode:  177 score 233.90 average_score 101.05 epsilon 0.01
# episode:  178 score -26.18 average_score 98.91 epsilon 0.01
# episode:  179 score -60.42 average_score 97.90 epsilon 0.01
# episode:  180 score 189.26 average_score 100.05 epsilon 0.01
# episode:  181 score 260.49 average_score 100.84 epsilon 0.01
# episode:  182 score 188.56 average_score 102.11 epsilon 0.01
# episode:  183 score 234.06 average_score 104.06 epsilon 0.01
# episode:  184 score -23.59 average_score 103.71 epsilon 0.01
# episode:  185 score -11.24 average_score 104.24 epsilon 0.01
# episode:  186 score 258.39 average_score 110.00 epsilon 0.01
# episode:  187 score 185.42 average_score 113.26 epsilon 0.01
# episode:  188 score -330.78 average_score 111.10 epsilon 0.01
# episode:  189 score 283.92 average_score 114.79 epsilon 0.01
# episode:  190 score -58.42 average_score 112.60 epsilon 0.01
# episode:  191 score 219.00 average_score 112.85 epsilon 0.01
# episode:  192 score 252.00 average_score 115.21 epsilon 0.01
# episode:  193 score 209.56 average_score 117.45 epsilon 0.01
# episode:  194 score -35.24 average_score 119.01 epsilon 0.01
# episode:  195 score 269.04 average_score 121.32 epsilon 0.01
# episode:  196 score -66.58 average_score 121.69 epsilon 0.01
# episode:  197 score 193.06 average_score 122.15 epsilon 0.01
# episode:  198 score 243.85 average_score 125.08 epsilon 0.01
# episode:  199 score 224.31 average_score 127.09 epsilon 0.01
# episode:  200 score 181.73 average_score 128.88 epsilon 0.01
# episode:  201 score 188.69 average_score 131.36 epsilon 0.01
# episode:  202 score 262.10 average_score 132.01 epsilon 0.01
# episode:  203 score 226.97 average_score 134.20 epsilon 0.01
# episode:  204 score 206.14 average_score 136.16 epsilon 0.01
# episode:  205 score -149.89 average_score 135.90 epsilon 0.01
# episode:  206 score 241.18 average_score 140.20 epsilon 0.01
# episode:  207 score 241.07 average_score 140.92 epsilon 0.01
# episode:  208 score 197.56 average_score 141.91 epsilon 0.01
# episode:  209 score 220.05 average_score 141.31 epsilon 0.01
# episode:  210 score 191.15 average_score 140.95 epsilon 0.01
# episode:  211 score 222.05 average_score 144.54 epsilon 0.01
# episode:  212 score 256.05 average_score 147.58 epsilon 0.01
# episode:  213 score -126.70 average_score 144.32 epsilon 0.01
# episode:  214 score 249.21 average_score 144.76 epsilon 0.01
# episode:  215 score 267.53 average_score 145.37 epsilon 0.01
# episode:  216 score -57.47 average_score 142.87 epsilon 0.01
# episode:  217 score -255.86 average_score 140.93 epsilon 0.01
# episode:  218 score 192.89 average_score 141.07 epsilon 0.01
# episode:  219 score -20.56 average_score 138.19 epsilon 0.01
# episode:  220 score -168.80 average_score 134.71 epsilon 0.01
# episode:  221 score -136.62 average_score 130.53 epsilon 0.01
# episode:  222 score 17.34 average_score 129.61 epsilon 0.01
# episode:  223 score 284.73 average_score 132.24 epsilon 0.01
# episode:  224 score 261.16 average_score 132.68 epsilon 0.01
# episode:  225 score 245.40 average_score 133.09 epsilon 0.01
# episode:  226 score 257.44 average_score 135.13 epsilon 0.01
# episode:  227 score 196.26 average_score 140.08 epsilon 0.01
# episode:  228 score -112.80 average_score 139.28 epsilon 0.01
# episode:  229 score 187.77 average_score 139.00 epsilon 0.01
# episode:  230 score 243.11 average_score 139.45 epsilon 0.01
# episode:  231 score 260.92 average_score 139.54 epsilon 0.01
# episode:  232 score 278.37 average_score 140.35 epsilon 0.01
# episode:  233 score 293.02 average_score 140.75 epsilon 0.01
# episode:  234 score 190.21 average_score 140.47 epsilon 0.01
# episode:  235 score 222.37 average_score 140.58 epsilon 0.01
# episode:  236 score 163.47 average_score 141.95 epsilon 0.01
# episode:  237 score 281.83 average_score 142.65 epsilon 0.01
# episode:  238 score 241.57 average_score 142.15 epsilon 0.01
# episode:  239 score 250.71 average_score 144.54 epsilon 0.01
# episode:  240 score 15.15 average_score 142.29 epsilon 0.01
# episode:  241 score 261.36 average_score 142.77 epsilon 0.01
# episode:  242 score 246.79 average_score 145.30 epsilon 0.01
# episode:  243 score 235.20 average_score 145.26 epsilon 0.01
# episode:  244 score 261.03 average_score 148.28 epsilon 0.01
# episode:  245 score 185.20 average_score 147.78 epsilon 0.01
# episode:  246 score 291.79 average_score 148.80 epsilon 0.01
# episode:  247 score 231.27 average_score 148.68 epsilon 0.01
# episode:  248 score 284.10 average_score 149.61 epsilon 0.01
# episode:  249 score 174.11 average_score 149.48 epsilon 0.01
# episode:  250 score 235.12 average_score 149.30 epsilon 0.01
# episode:  251 score 280.70 average_score 149.83 epsilon 0.01
# episode:  252 score 207.88 average_score 149.80 epsilon 0.01
# episode:  253 score 142.67 average_score 148.66 epsilon 0.01
# episode:  254 score 258.21 average_score 150.96 epsilon 0.01
# episode:  255 score 132.26 average_score 150.22 epsilon 0.01
# episode:  256 score 217.17 average_score 150.57 epsilon 0.01
# episode:  257 score 235.38 average_score 153.05 epsilon 0.01
# episode:  258 score 202.26 average_score 158.30 epsilon 0.01
# episode:  259 score 219.34 average_score 161.46 epsilon 0.01
# episode:  260 score 282.02 average_score 164.94 epsilon 0.01
# episode:  261 score 75.35 average_score 166.59 epsilon 0.01
# episode:  262 score 250.98 average_score 167.28 epsilon 0.01
# episode:  263 score 239.12 average_score 167.21 epsilon 0.01
# episode:  264 score 286.53 average_score 167.75 epsilon 0.01
# episode:  265 score 239.93 average_score 167.50 epsilon 0.01
# episode:  266 score 192.32 average_score 169.41 epsilon 0.01
# episode:  267 score 211.27 average_score 168.53 epsilon 0.01
# episode:  268 score 196.53 average_score 171.60 epsilon 0.01
# episode:  269 score 204.64 average_score 171.25 epsilon 0.01
# episode:  270 score -53.62 average_score 169.58 epsilon 0.01
# episode:  271 score 241.46 average_score 169.63 epsilon 0.01
# episode:  272 score 277.06 average_score 169.94 epsilon 0.01
# episode:  273 score 269.33 average_score 169.87 epsilon 0.01
# episode:  274 score 262.10 average_score 170.00 epsilon 0.01
# episode:  275 score 274.65 average_score 169.96 epsilon 0.01
# episode:  276 score 249.45 average_score 170.40 epsilon 0.01
# episode:  277 score 271.41 average_score 170.77 epsilon 0.01
# episode:  278 score 272.12 average_score 173.76 epsilon 0.01
# episode:  279 score 256.89 average_score 176.93 epsilon 0.01
# episode:  280 score 287.82 average_score 177.92 epsilon 0.01
# episode:  281 score 276.92 average_score 178.08 epsilon 0.01
# episode:  282 score 251.19 average_score 178.71 epsilon 0.01
# episode:  283 score 223.39 average_score 178.60 epsilon 0.01
# episode:  284 score 230.05 average_score 181.14 epsilon 0.01
# episode:  285 score 262.03 average_score 183.87 epsilon 0.01
# episode:  286 score -0.05 average_score 181.28 epsilon 0.01
# episode:  287 score 237.16 average_score 181.80 epsilon 0.01
# episode:  288 score 269.03 average_score 187.80 epsilon 0.01
# episode:  289 score 263.29 average_score 187.59 epsilon 0.01
# episode:  290 score -39.44 average_score 187.78 epsilon 0.01
# episode:  291 score 241.52 average_score 188.01 epsilon 0.01
# episode:  292 score 271.27 average_score 188.20 epsilon 0.01
# episode:  293 score 227.41 average_score 188.38 epsilon 0.01
# episode:  294 score 188.99 average_score 190.62 epsilon 0.01
# episode:  295 score 275.71 average_score 190.69 epsilon 0.01
# episode:  296 score 249.25 average_score 193.85 epsilon 0.01
# episode:  297 score -215.42 average_score 189.76 epsilon 0.01
# episode:  298 score 252.42 average_score 189.85 epsilon 0.01
# episode:  299 score 219.65 average_score 189.80 epsilon 0.01
# episode:  300 score 310.46 average_score 191.09 epsilon 0.01
# episode:  301 score 47.78 average_score 189.68 epsilon 0.01
# episode:  302 score -74.86 average_score 186.31 epsilon 0.01
# episode:  303 score -64.01 average_score 183.40 epsilon 0.01
# episode:  304 score 252.44 average_score 183.86 epsilon 0.01
# episode:  305 score 224.25 average_score 187.60 epsilon 0.01
# episode:  306 score 306.46 average_score 188.26 epsilon 0.01
# episode:  307 score 204.53 average_score 187.89 epsilon 0.01
# episode:  308 score 221.14 average_score 188.13 epsilon 0.01
# episode:  309 score 238.05 average_score 188.31 epsilon 0.01
# episode:  310 score 272.13 average_score 189.12 epsilon 0.01
# episode:  311 score 280.22 average_score 189.70 epsilon 0.01
# episode:  312 score 242.93 average_score 189.57 epsilon 0.01
# episode:  313 score 265.22 average_score 193.49 epsilon 0.01
# episode:  314 score 246.83 average_score 193.46 epsilon 0.01
# episode:  315 score -228.47 average_score 188.50 epsilon 0.01
# episode:  316 score 237.24 average_score 191.45 epsilon 0.01
# episode:  317 score -172.74 average_score 192.28 epsilon 0.01
# episode:  318 score 183.21 average_score 192.18 epsilon 0.01
# episode:  319 score 222.39 average_score 194.61 epsilon 0.01
# episode:  320 score -106.15 average_score 195.24 epsilon 0.01
# episode:  321 score 231.83 average_score 198.92 epsilon 0.01
# episode:  322 score 284.44 average_score 201.60 epsilon 0.01
# episode:  323 score 255.69 average_score 201.31 epsilon 0.01
# episode:  324 score 236.15 average_score 201.06 epsilon 0.01
# episode:  325 score 244.91 average_score 201.05 epsilon 0.01
# episode:  326 score 193.29 average_score 200.41 epsilon 0.01
# episode:  327 score 240.01 average_score 200.85 epsilon 0.01
# episode:  328 score 263.11 average_score 204.61 epsilon 0.01
# episode:  329 score 211.66 average_score 204.84 epsilon 0.01
# episode:  330 score 161.04 average_score 204.02 epsilon 0.01
# episode:  331 score 200.89 average_score 203.42 epsilon 0.01
# episode:  332 score 172.35 average_score 202.36 epsilon 0.01
# episode:  333 score 216.76 average_score 201.60 epsilon 0.01
# episode:  334 score 267.28 average_score 202.37 epsilon 0.01
# episode:  335 score 236.90 average_score 202.52 epsilon 0.01
# episode:  336 score 250.15 average_score 203.38 epsilon 0.01
# episode:  337 score 223.84 average_score 202.80 epsilon 0.01
# episode:  338 score 281.88 average_score 203.21 epsilon 0.01
# episode:  339 score 160.85 average_score 202.31 epsilon 0.01
# episode:  340 score 251.57 average_score 204.67 epsilon 0.01
# episode:  341 score 259.66 average_score 204.66 epsilon 0.01
# episode:  342 score 251.57 average_score 204.70 epsilon 0.01
# episode:  343 score 268.22 average_score 205.03 epsilon 0.01
# episode:  344 score 282.18 average_score 205.24 epsilon 0.01
# episode:  345 score 243.45 average_score 205.83 epsilon 0.01
# episode:  346 score 231.98 average_score 205.23 epsilon 0.01
# episode:  347 score 290.25 average_score 205.82 epsilon 0.01
# episode:  348 score 274.38 average_score 205.72 epsilon 0.01
# episode:  349 score 201.23 average_score 205.99 epsilon 0.01
# episode:  350 score 236.64 average_score 206.01 epsilon 0.01
# episode:  351 score 281.38 average_score 206.02 epsilon 0.01
# episode:  352 score 227.63 average_score 206.21 epsilon 0.01
# episode:  353 score 245.07 average_score 207.24 epsilon 0.01
# episode:  354 score 237.88 average_score 207.03 epsilon 0.01
# episode:  355 score -28.26 average_score 205.43 epsilon 0.01
# episode:  356 score 247.25 average_score 205.73 epsilon 0.01
# episode:  357 score 243.09 average_score 205.81 epsilon 0.01
# episode:  358 score 57.08 average_score 204.35 epsilon 0.01
# episode:  359 score 267.58 average_score 204.84 epsilon 0.01
# episode:  360 score 283.12 average_score 204.85 epsilon 0.01
# episode:  361 score 214.04 average_score 206.23 epsilon 0.01
# episode:  362 score 268.56 average_score 206.41 epsilon 0.01
# episode:  363 score 145.89 average_score 205.48 epsilon 0.01
# episode:  364 score 261.76 average_score 205.23 epsilon 0.01
# episode:  365 score -214.28 average_score 200.69 epsilon 0.01
# episode:  366 score 240.02 average_score 201.17 epsilon 0.01
# episode:  367 score 258.56 average_score 201.64 epsilon 0.01
# episode:  368 score 224.68 average_score 201.92 epsilon 0.01
# episode:  369 score 243.17 average_score 202.30 epsilon 0.01
# episode:  370 score 253.80 average_score 205.38 epsilon 0.01
# episode:  371 score 300.97 average_score 205.97 epsilon 0.01
# episode:  372 score 259.43 average_score 205.80 epsilon 0.01
# episode:  373 score 245.72 average_score 205.56 epsilon 0.01
# episode:  374 score -304.65 average_score 199.89 epsilon 0.01
# episode:  375 score 251.44 average_score 199.66 epsilon 0.01
# episode:  376 score 242.82 average_score 199.60 epsilon 0.01
# episode:  377 score 227.40 average_score 199.16 epsilon 0.01
# episode:  378 score 253.71 average_score 198.97 epsilon 0.01
# episode:  379 score 221.40 average_score 198.62 epsilon 0.01
# episode:  380 score -41.88 average_score 195.32 epsilon 0.01
# episode:  381 score 239.97 average_score 194.95 epsilon 0.01
# episode:  382 score 274.47 average_score 195.18 epsilon 0.01
# episode:  383 score -231.27 average_score 190.64 epsilon 0.01
# episode:  384 score 121.13 average_score 189.55 epsilon 0.01
# episode:  385 score 234.28 average_score 189.27 epsilon 0.01
# episode:  386 score 214.25 average_score 191.41 epsilon 0.01
# episode:  387 score 264.12 average_score 191.68 epsilon 0.01
# episode:  388 score 309.83 average_score 192.09 epsilon 0.01
# episode:  389 score 261.79 average_score 192.08 epsilon 0.01
# episode:  390 score 224.43 average_score 194.71 epsilon 0.01
# episode:  391 score 258.43 average_score 194.88 epsilon 0.01
# episode:  392 score 168.77 average_score 193.86 epsilon 0.01
# episode:  393 score 191.49 average_score 193.50 epsilon 0.01
# episode:  394 score 248.60 average_score 194.10 epsilon 0.01
# episode:  395 score 190.66 average_score 193.24 epsilon 0.01
# episode:  396 score 247.59 average_score 193.23 epsilon 0.01
# episode:  397 score 221.08 average_score 197.59 epsilon 0.01
# episode:  398 score 35.46 average_score 195.42 epsilon 0.01
# episode:  399 score 226.31 average_score 195.49 epsilon 0.01
# episode:  400 score 268.41 average_score 195.07 epsilon 0.01
# episode:  401 score 219.67 average_score 196.79 epsilon 0.01
# episode:  402 score 205.41 average_score 199.59 epsilon 0.01
# episode:  403 score 226.84 average_score 202.50 epsilon 0.01
# episode:  404 score -39.01 average_score 199.59 epsilon 0.01
# episode:  405 score -24.16 average_score 197.10 epsilon 0.01
# episode:  406 score 198.52 average_score 196.02 epsilon 0.01
# episode:  407 score 224.96 average_score 196.23 epsilon 0.01
# episode:  408 score 244.12 average_score 196.46 epsilon 0.01
# episode:  409 score 201.67 average_score 196.09 epsilon 0.01
# episode:  410 score 222.13 average_score 195.59 epsilon 0.01
# episode:  411 score 266.41 average_score 195.45 epsilon 0.01
# episode:  412 score 282.11 average_score 195.85 epsilon 0.01
# episode:  413 score 261.34 average_score 195.81 epsilon 0.01
# episode:  414 score 274.90 average_score 196.09 epsilon 0.01
# episode:  415 score 222.08 average_score 200.59 epsilon 0.01
# episode:  416 score 256.99 average_score 200.79 epsilon 0.01
# episode:  417 score 280.11 average_score 205.32 epsilon 0.01
# episode:  418 score 282.87 average_score 206.32 epsilon 0.01
# episode:  419 score 266.56 average_score 206.76 epsilon 0.01
# episode:  420 score 218.99 average_score 210.01 epsilon 0.01
# episode:  421 score 257.10 average_score 210.26 epsilon 0.01
# episode:  422 score 251.11 average_score 209.93 epsilon 0.01
# episode:  423 score 233.18 average_score 209.70 epsilon 0.01
# episode:  424 score 249.69 average_score 209.84 epsilon 0.01
# episode:  425 score 272.75 average_score 210.12 epsilon 0.01
# episode:  426 score 232.10 average_score 210.50 epsilon 0.01
# episode:  427 score 279.21 average_score 210.90 epsilon 0.01
# episode:  428 score 241.39 average_score 210.68 epsilon 0.01
# episode:  429 score 8.95 average_score 208.65 epsilon 0.01
# episode:  430 score 233.82 average_score 209.38 epsilon 0.01
# episode:  431 score 223.91 average_score 209.61 epsilon 0.01
# episode:  432 score 265.04 average_score 210.54 epsilon 0.01
# episode:  433 score 242.70 average_score 210.80 epsilon 0.01
# episode:  434 score 259.25 average_score 210.72 epsilon 0.01
# episode:  435 score 199.88 average_score 210.35 epsilon 0.01
# episode:  436 score 272.09 average_score 210.57 epsilon 0.01
# episode:  437 score 232.29 average_score 210.65 epsilon 0.01
# episode:  438 score 189.22 average_score 209.72 epsilon 0.01
# episode:  439 score 203.51 average_score 210.15 epsilon 0.01
# episode:  440 score 258.12 average_score 210.22 epsilon 0.01
# episode:  441 score 276.28 average_score 210.38 epsilon 0.01
# episode:  442 score 289.11 average_score 210.76 epsilon 0.01
# episode:  443 score 257.81 average_score 210.65 epsilon 0.01
# episode:  444 score 255.35 average_score 210.39 epsilon 0.01
# episode:  445 score 267.19 average_score 210.62 epsilon 0.01
# episode:  446 score 240.44 average_score 210.71 epsilon 0.01
# episode:  447 score 248.62 average_score 210.29 epsilon 0.01
# episode:  448 score 276.76 average_score 210.31 epsilon 0.01
# episode:  449 score 246.92 average_score 210.77 epsilon 0.01
# episode:  450 score 304.12 average_score 211.45 epsilon 0.01
# episode:  451 score 196.66 average_score 210.60 epsilon 0.01
# episode:  452 score 278.45 average_score 211.11 epsilon 0.01
# episode:  453 score 272.19 average_score 211.38 epsilon 0.01
# episode:  454 score 274.16 average_score 211.74 epsilon 0.01
# episode:  455 score 255.02 average_score 214.57 epsilon 0.01
# episode:  456 score -121.24 average_score 210.89 epsilon 0.01
# episode:  457 score 279.60 average_score 211.25 epsilon 0.01
# episode:  458 score 265.54 average_score 213.34 epsilon 0.01
# episode:  459 score 234.09 average_score 213.00 epsilon 0.01
# episode:  460 score 277.34 average_score 212.95 epsilon 0.01
# episode:  461 score 253.64 average_score 213.34 epsilon 0.01
# episode:  462 score 239.21 average_score 213.05 epsilon 0.01
# episode:  463 score 235.51 average_score 213.94 epsilon 0.01
# episode:  464 score 207.04 average_score 213.40 epsilon 0.01
# episode:  465 score 262.10 average_score 218.16 epsilon 0.01
# episode:  466 score 274.59 average_score 218.51 epsilon 0.01
# episode:  467 score 264.28 average_score 218.56 epsilon 0.01
# episode:  468 score 269.09 average_score 219.01 epsilon 0.01
# episode:  469 score -77.81 average_score 215.80 epsilon 0.01
# episode:  470 score -24.18 average_score 213.02 epsilon 0.01
# episode:  471 score 281.43 average_score 212.82 epsilon 0.01
# episode:  472 score 275.69 average_score 212.99 epsilon 0.01
# episode:  473 score 282.89 average_score 213.36 epsilon 0.01
# episode:  474 score 236.37 average_score 218.77 epsilon 0.01
# episode:  475 score 278.96 average_score 219.04 epsilon 0.01
# episode:  476 score 264.30 average_score 219.26 epsilon 0.01
# episode:  477 score 282.58 average_score 219.81 epsilon 0.01
# episode:  478 score 274.81 average_score 220.02 epsilon 0.01
# episode:  479 score 259.56 average_score 220.40 epsilon 0.01
# episode:  480 score 244.98 average_score 223.27 epsilon 0.01
# episode:  481 score 256.29 average_score 223.43 epsilon 0.01
# episode:  482 score 236.71 average_score 223.06 epsilon 0.01
# episode:  483 score 262.85 average_score 228.00 epsilon 0.01
# episode:  484 score 251.54 average_score 229.30 epsilon 0.01
# episode:  485 score 277.15 average_score 229.73 epsilon 0.01
# episode:  486 score 253.53 average_score 230.12 epsilon 0.01
# episode:  487 score 252.77 average_score 230.01 epsilon 0.01
# episode:  488 score 263.49 average_score 229.55 epsilon 0.01
# episode:  489 score 256.65 average_score 229.49 epsilon 0.01
# episode:  490 score 213.15 average_score 229.38 epsilon 0.01
# episode:  491 score 241.33 average_score 229.21 epsilon 0.01
# episode:  492 score 268.83 average_score 230.21 epsilon 0.01
# episode:  493 score 282.50 average_score 231.12 epsilon 0.01
# episode:  494 score 215.15 average_score 230.79 epsilon 0.01
